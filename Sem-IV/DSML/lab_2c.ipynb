# %%
import pandas as pd
import matplotlib
import scipy
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("temperatures.csv")
# print(data.head())
D=data.head()
print(D)
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
D.describe()
# Out:
#               YEAR        JAN        FEB      MAR        APR        MAY  \
# count     5.000000   5.000000   5.000000   5.0000   5.000000   5.000000
# mean   1903.000000  23.054000  24.662000  28.3120  31.422000  33.202000
# std       1.581139   1.174087   1.364504   1.1839   0.824421   0.429267
# min    1901.000000  22.000000  22.830000  26.6800  30.010000  32.640000
# 25%    1902.000000  22.400000  24.140000  27.8300  31.390000  32.910000
# 50%    1903.000000  22.500000  24.730000  28.2100  31.780000  33.320000
# 75%    1904.000000  23.440000  25.030000  29.0700  31.910000  33.410000
# max    1905.000000  24.930000  26.580000  29.7700  32.020000  33.730000
#
#              JUN        JUL        AUG        SEP        OCT        NOV  \
# count   5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   32.882000  31.054000  30.374000  30.056000  29.600000  26.716000
# std     0.473888   0.434373   0.337831   0.266327   0.704592   0.651022
# min    32.070000  30.360000  29.980000  29.800000  29.040000  26.080000
# 25%    32.910000  30.920000  30.090000  29.850000  29.120000  26.310000
# 50%    33.000000  31.210000  30.390000  30.040000  29.200000  26.360000
# 75%    33.180000  31.340000  30.680000  30.120000  29.970000  27.310000
# max    33.250000  31.440000  30.730000  30.470000  30.670000  27.520000
#
#              DEC     ANNUAL    JAN-FEB    MAR-MAY    JUN-SEP    OCT-DEC
# count   5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   23.926000  28.688000  23.826000  30.976000  31.054000  26.594000
# std     0.355711   0.385448   1.295041   0.684273   0.272635   0.384357
# min    23.630000  28.300000  22.250000  30.000000  30.660000  26.260000
# 25%    23.650000  28.470000  23.270000  30.710000  30.920000  26.400000
# 50%    23.820000  28.490000  23.620000  30.950000  31.090000  26.490000
# 75%    24.040000  28.960000  24.240000  31.460000  31.270000  26.570000
# max    24.490000  29.220000  25.750000  31.760000  31.330000  27.250000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['YEAR'].plot(kind='hist', bins=20, title='YEAR')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['JAN'].plot(kind='hist', bins=20, title='JAN')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['FEB'].plot(kind='hist', bins=20, title='FEB')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['MAR'].plot(kind='hist', bins=20, title='MAR')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='YEAR', y='JAN', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='JAN', y='FEB', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='FEB', y='MAR', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='MAR', y='APR', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['YEAR']
#   ys = series['JAN']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('YEAR', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('YEAR')
# _ = plt.ylabel('JAN')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['YEAR']
#   ys = series['FEB']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('YEAR', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('YEAR')
# _ = plt.ylabel('FEB')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['YEAR']
#   ys = series['MAR']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('YEAR', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('YEAR')
# _ = plt.ylabel('MAR')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['YEAR']
#   ys = series['APR']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('YEAR', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('YEAR')
# _ = plt.ylabel('APR')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['YEAR'].plot(kind='line', figsize=(8, 4), title='YEAR')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['JAN'].plot(kind='line', figsize=(8, 4), title='JAN')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['FEB'].plot(kind='line', figsize=(8, 4), title='FEB')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['MAR'].plot(kind='line', figsize=(8, 4), title='MAR')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Drop rows with missing values
D.dropna(inplace=True)

# Fill missing values with a specific value
D.fillna(value, inplace=True)
# Out:
# <ipython-input-8-c28dd3d1edea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   D.dropna(inplace=True)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c28dd3d1edea> in <cell line: 5>()
#       3
#       4 # Fill missing values with a specific value
# ----> 5 D.fillna(value, inplace=True)
#
# NameError: name 'value' is not defined
